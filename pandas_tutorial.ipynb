# %% [markdown]
# <a href="https://colab.research.google.com/github/rsnbgt/python_tutorial/blob/main/pandas_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pandas Tutorial

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %%
# sereis=1-D column of data
vehicles=pd.Series(['cars','buses','trucks'])
print(vehicles)
# Out:
# 0      cars
# 1     buses
# 2    trucks
# dtype: object

# %%
# dataframe=2-D table of data
data=pd.DataFrame({'vehicles types':vehicles,
                   'color': 'red'})
print(data)
# Out:
#   vehicles types color
# 0           cars   red
# 1          buses   red
# 2         trucks   red

# %% [markdown]
# importing and exporting data

# %%
# pd.read_csv()
# pd.read_excel()
df=pd.read_csv('./sample_data/california_housing_train.csv')
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
# to export
sales=df.to_csv('./sample_data/sales.csv')

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
# dtypes: float64(9)
# memory usage: 1.2 MB

# %%
df.mean(numeric_only='true')
# Out:
# longitude               -119.562108
# latitude                  35.625225
# housing_median_age        28.589353
# total_rooms             2643.664412
# total_bedrooms           539.410824
# population              1429.573941
# households               501.221941
# median_income              3.883578
# median_house_value    207300.912353
# dtype: float64

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
df.sum()
# Out:
# longitude            -2.032556e+06
# latitude              6.056288e+05
# housing_median_age    4.860190e+05
# total_rooms           4.494230e+07
# total_bedrooms        9.169984e+06
# population            2.430276e+07
# households            8.520773e+06
# median_income         6.602083e+04
# median_house_value    3.524116e+09
# dtype: float64

# %%
df.index
# Out:
# RangeIndex(start=0, stop=17000, step=1)

# %%
# DataFrame.head(n=5) - Displays the first n rows of a DataFrame
# DataFrame.tail(n=5) - Displays the last n rows of a DataFrame
# DataFrame.loc[] - Accesses a group of rows and columns by labels or a boolean array
# DataFrame.iloc[] - Accesses a group of rows and columns by integer indices
# DataFrame.columns - Lists the column labels of the DataFrame
# DataFrame['A'] - Selects the column named 'A' from the DataFrame
# DataFrame[DataFrame['A'] > 5] - Boolean indexing filters rows based on column values meeting a condition
# DataFrame.plot() - Creates a line plot of a DataFrame's columns
# DataFrame.hist() - Generates histograms for columns in a DataFrame
# pandas.crosstab() - Computes a cross-tabulation of two or more factors
df.plot()
df.hist()
#pd.crosstab(df['longitude'],df['median_house_value'])
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
df.groupby('housing_median_age').mean(numeric_only='true')
# Out:
#                      longitude   latitude  total_rooms  total_bedrooms  \
# housing_median_age
# 1.0                -121.465000  37.940000  2158.000000      335.500000
# 2.0                -119.035306  35.410816  5237.102041      871.448980
# 3.0                -118.798478  35.164783  6920.326087     1190.826087
# 4.0                -118.805093  34.987764  6065.614907     1068.192547
# 5.0                -118.789497  35.095327  4926.261307      910.924623
# 6.0                -118.915969  35.183798  4365.062016      821.550388
# 7.0                -119.165497  35.627616  5672.907285     1047.350993
# 8.0                -119.375056  35.785899  4076.786517      779.252809
# 9.0                -119.324186  35.654942  3813.465116      727.401163
# 10.0               -119.350841  35.881681  3518.482301      681.508850
# 11.0               -119.517837  35.930288  3971.105769      768.932692
# 12.0               -119.405000  35.806458  4216.661458      838.843750
# ...

# %%
# df.fillna() -fills empty values with a specified value
# df.dropna() -removes rows with empty values
# You can remove a column using .drop('COLUMN_NAME', axis=1)
